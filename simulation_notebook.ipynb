# %%
from pandas_datareader import data
import pandas_montecarlo

df = data.get_data_yahoo("SPY")
df["return"] = df["Adj Close"].pct_change().fillna(0)

mc = df["return"].montecarlo(sims=10, bust=-0.1, goal=1)

# %%
mc.plot(title="SPY Returns Monte Carlo Simulations")

# %%
print(mc.stats)
print(mc.maxdd)
# Out:
# {'min': 0.8897287727721497, 'max': 0.8897287727721501, 'mean': 0.8897287727721498, 'median': 0.8897287727721497, 'std': 1.8870162890012254e-16, 'maxdd': -0.3024947659841606, 'bust': 0.4, 'goal': 0.0}
# {'min': -0.3024947659841606, 'max': -0.020881522861338153, 'mean': -0.11625095689779767, 'median': -0.07943512903614441, 'std': 0.10052166834959214}
